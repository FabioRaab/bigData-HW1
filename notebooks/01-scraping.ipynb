# %% [markdown]
# # Website scraping
#
# ---
#
# Group name: O
#
# ---

# %% [markdown]
# **Set up**

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# **Scraping mit request**

# %%
url ='https://fivethirtyeight.com/features/a-blue-nevada-means-democrats-will-keep-control-of-the-senate/'

# %% [markdown]
# **Check if response is correct**

# %%
html = requests.get(url)

# %%
assert html.status_code == 200
assert html.url == "https://fivethirtyeight.com/features/a-blue-nevada-means-democrats-will-keep-control-of-the-senate/"

# %%
html.status_code
# Out:
# 200

# %% [markdown]
# **Get the Text with BeautifulSoup**

# %%
soup = BeautifulSoup(html.text, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <link href="//dcf.espn.com" rel="dns-prefetch"/>
#   <script type="text/javascript">
#    function setCookie(name,value,days) {
# 				var expires = "";
# 				if (days) {
# 					var date = new Date();
# 					date.setTime(date.getTime() + (days*24*60*60*1000));
# 					expires = "; expires=" + date.toUTCString();
# 				}
# 				document.cookie = name + "=" + (value || "") + expires + "; path=/";
# 			}
# 			setCookie('country','ca',1);
#   </script>
#   <script src="https://dcf.espn.com/TWDC-DTCI/prod/Bootstrap.js">
#   </script>
#   <title>
#    A Blue Nevada Means Democrats Will Keep Control Of The Senate | FiveThirtyEight
#   </title>
#   <meta content="max-image-preview:large" name="robots">
# ...

# %%
# Out:
# [<p data-paragraph="main">For Democrats, the Silver State is gold: ABC News has reported that Democratic Sen. Catherine Cortez Masto <a href="https://abcnews.go.com/Politics/live-updates/midterm-elections-live-updates/?id=92681028#93191881" rel="noopener" target="_blank">is projected to win</a> reelection in <a href="https://abcnews.go.com/Politics/nevada-2022-midterm-election-results/story?id=92010185" rel="noopener" target="_blank">Nevada</a>. This projection confirms that Democrats will retain at least 50 seats in the U.S. Senate and, with Vice President Kamala Harris’s tie-breaking vote, guarantees Democrats a slim majority in Congress’s upper chamber.</p>,
# ...

# %%
print(soup.get_text())
# Out:
# A Blue Nevada Means Democrats Will Keep Control Of The Senate | FiveThirtyEight
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Skip to main content
#
#
#
#
#
#
#
# FiveThirtyEight
#
#
#
#
#
# Search
#
#
#
# Search
#
#
#
#
# ABC News
#
# Menu
#
#
#
#
# 											A Blue Nevada Means Democrats Will Keep Control Of The Senate
# Share on Facebook
# Share on Twitter
#
#
#
#
#
#
# 						Politics
#
#
#
# 						Sports
#
#
#
# 						Science
#
#
#
# 						Podcasts
#
#
#
# 						Video
#
#
#
# 						ABC News
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 2022 Election
# A Blue Nevada Means Democrats Will Keep Control Of The Senate
#
#
#
# By Geoffrey Skelley
#
#
# 									Nov. 12, 2022, at 10:00 PM
#
#
#
#
#
#
#
#
# PHOTO ILLUSTRATION BY FIVETHIRTYEIGHT / GETTY IMAGES
#
#
# ...

# %%
soup.title
# Out:
# <title>A Blue Nevada Means Democrats Will Keep Control Of The Senate | FiveThirtyEight</title>

# %%
soup.title.string
# Out:
# 'A Blue Nevada Means Democrats Will Keep Control Of The Senate | FiveThirtyEight'

# %%
title_text=[]
title_text.append(soup.title.text)
title_text
# Out:
# ['A Blue Nevada Means Democrats Will Keep Control Of The Senate | FiveThirtyEight']

# %%
author_text=[]
for i in soup.find_all('a', {'class': 'author'}):
    a=(i.text)
    author_text.append(a)

author_text
# Out:
# ['Geoffrey Skelley']

# %%
subtitle_all = soup.find_all('h2', {'class': 'title'})
subtitle_all
# Out:
# [<h2 class="title">Democrats held most key seats and gained Pennsylvania</h2>]

# %%
subtitle_text=[]
for i in subtitle_all:
    subtitle_text.append(i.text.replace('\n','').replace('    ',''))

subtitle_text
# Out:
# ['Democrats held most key seats and gained Pennsylvania']

# %%
subtitle2_all = soup.find_all('h3')
subtitle2_all
# Out:
# [<h3 class="video-title">Who will have the advantage in the Georgia runoff? | FiveThirtyEight</h3>,
#  <h3 class="fte-expandable-title">Comments</h3>,
#  <h3 class="more-in-topic-heading">More in 2022 Election</h3>,
#  <h3>Latest</h3>]

# %%
subtitle2_text=[]
for i in subtitle2_all:
    subtitle2_text.append(i.text.replace('\n','').replace('    ',''))

subtitle2_text
# Out:
# ['Who will have the advantage in the Georgia runoff? | FiveThirtyEight',
#  'Comments',
#  'More in 2022 Election',
#  'Latest']

# %%
text_all = soup.find_all('div', {'id': 'article-main'})
text_all
# Out:
# [<div id="article-main">
#  <article class="post-350220 fte_features type-fte_features status-publish has-post-thumbnail hentry tag-2022-election tag-2022-midterms tag-catherine-cortez-masto tag-coin-flips tag-democrats tag-georgia-senate-runoff tag-mark-kelly tag-senate-democrats tag-senate-republicans tag-swing-states espn_verticals-politics vertical-politics topic-slug-2022-election" id="post-350220">
#  <div class="entry-content single-post-content">
#  <div class="wp-block-abc-blocks-article-header abc-blocks-article-header--short-form abc-blocks-article-header--default abc-blocks-article-header--without-dek">
#  <div class="abc-blocks-article-header__container">
#  <header class="post-info single-post-header"><div class="single-header">
#  <p class="single-metadata single-topic"><a class="term" href="https://fivethirtyeight.com/tag/2022-election/" name="">2022 Election</a></p>
# ...

# %%
article_text=[]
for i in text_all:
    article_text.append(i.text.replace('\n','').replace('\xa0—\xa0','').replace('                 ',''))

article_text
# Out:
# ['2022 ElectionA Blue Nevada Means Democrats Will Keep Control Of The SenateBy Geoffrey Skelley\t\t\t\t\t\t\t\t\tNov. 12, 2022, at 10:00 PM\t\t\t\t\t\t\t\t PHOTO ILLUSTRATION BY FIVETHIRTYEIGHT / GETTY IMAGESFor Democrats, the Silver State is gold: ABC News has reported that Democratic Sen. Catherine Cortez Masto is projected to win reelection in Nevada. This projection confirms that Democrats will retain at least 50 seats in the U.S. Senate and, with Vice President Kamala Harris’s tie-breaking vote, guarantees Democrats a slim majority in Congress’s upper chamber.The Nevada news comes on the heels of a projection in Arizona’s Senate race on Friday night, when it became clear that Democratic Sen. Mark Kelly would win reelection in the Grand Canyon State. We now know the partisan makeup of the next Senate, with the lone exception of Georgia, which will go to a runoff on Dec. 6. (Alaska has yet to be projected, but one of the two GOP contenders will win it.)These results are unusual fo
# ...

# %%
df_author = pd.DataFrame({"Author" : author_text})
df_author
# Out:
#              Author
# 0  Geoffrey Skelley

# %%
df_title = pd.DataFrame({"Title" : title_text})
df_title
# Out:
#                                                Title
# 0  A Blue Nevada Means Democrats Will Keep Contro...

# %%
df_subtitle = pd.DataFrame({"Subtitle h2" : subtitle_text})
df_subtitle
# Out:
#                                          Subtitle h2
# 0  Democrats held most key seats and gained Penns...

# %%
df_subtitle2 = pd.DataFrame({"Subtitle h3" : subtitle2_text})
df_subtitle2
# Out:
#                                          Subtitle h3
# 0  Who will have the advantage in the Georgia run...
# 1                                           Comments
# 2                              More in 2022 Election
# 3                                             Latest

# %%
df_text = pd.DataFrame({"Article-Text" : article_text})
df_text
# Out:
#                                         Article-Text
# 0  2022 ElectionA Blue Nevada Means Democrats Wil...

# %%
df1 = df_author.join(df_title)
df1
# Out:
#              Author                                              Title
# 0  Geoffrey Skelley  A Blue Nevada Means Democrats Will Keep Contro...

# %%
df2 = df1.join(df_subtitle)
df2
# Out:
#              Author                                              Title  \
# 0  Geoffrey Skelley  A Blue Nevada Means Democrats Will Keep Contro...
#
#                                          Subtitle h2
# 0  Democrats held most key seats and gained Penns...

# %%
df3 = df2.join(df_subtitle2)
df3
# Out:
#              Author                                              Title  \
# 0  Geoffrey Skelley  A Blue Nevada Means Democrats Will Keep Contro...
#
#                                          Subtitle h2  \
# 0  Democrats held most key seats and gained Penns...
#
#                                          Subtitle h3
# 0  Who will have the advantage in the Georgia run...
